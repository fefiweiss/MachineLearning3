# %% [markdown]
# #  Small Circle inside Large Circle
#
# #### Fernanda Weiss
# #### Fabián Fernandez

# %% [markdown]
# Lo siguiente es un problema de clasificación, en donde los datos a clasificar son modelos no-lineales y linealemente inseparables. Es inseparable ya que al tener datos de entrada $x \in R^2$ y su etiqueta correspondiente $y \in \{−1, 1\}$, no existe un vector de pesos $w \in R^2$ y $b \in R$ tal que $y(w^Tx + b) \geq \rho > 0$

# %% [markdown]
# ### a) Crear dataset de entrenamiento y prueba

# %% [markdown]
# (a) Escriba una funci´on que genere (aleatoriamente) n datos etiquetados de la forma {(x1, y1), . . . ,(xn, yn)}, xi ∈ R^2, yi ∈ {0, 1}, con una distribuci´on de probabilidad que refleje la configuraci´on linealmente inseparable que muestra la Fig. 13 . Utilice esta funci´on para crear 1000 datos de entrenamiento y 1000 datos de pruebas. Para medir la tendencia de los modelos a sobre-ajuste, agregue un 5 % de ruido al dataset, generando x’s cercanos a la frontera. Genere un gr´afico que muestre datos de entrenamiento y pruebas, identificando cada clase con un color diferente (como lo muestra la Fig. 1).

# %% [markdown]
# Se crean dos conjuntos de datos, uno de entrenamiento y otro de prueba, cada uno contiene 1.000 datos de la forma  $\{(x_1, y_1), . . . ,(x_n, y_n)\}$, $x_i ∈ R^2$, $yi \in \{0, 1\}$, con una distribución de probabilidad que refleje la configuración linealmente inseparable.
#
# Además se agrega un 5% de ruido a los datos, generando nuevos $x_i$ cercanos a la frontera.

# %%
import numpy as np
from sklearn.utils import check_random_state
from sklearn.model_selection import train_test_split
def do_circles(n=2000,noisy_n=0.05):
    generator = check_random_state(10)
    linspace = np.linspace(0, 2 * np.pi, n // 2 + 1)[:-1]
    outer_circ_x = np.cos(linspace)
    outer_circ_y = np.sin(linspace)
    inner_circ_x = outer_circ_x * .3
    inner_circ_y = outer_circ_y * .3
    X = np.vstack((np.append(outer_circ_x, inner_circ_x),np.append(outer_circ_y, inner_circ_y))).T
    
    y = np.hstack([np.zeros(n // 2, dtype=np.intp), np.ones(n // 2, dtype=np.intp)])
    
    X += generator.normal(scale=noisy_n, size=X.shape)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)
    return X_train,y_train,X_test,y_test

# %%
X_no_noisy,y_no_noisy,X_no_noisy_test,y_no_noisy_test = do_circles(2000, 0)

# %%
import matplotlib.pyplot as plt
def visualize(x,y,title=""):
    fig = plt.figure(figsize=(12,6))
    plt.scatter(x[:,0], x[:,1], s=50, c=y, cmap=plt.cm.winter)
    h = .02 # step size in the mesh
    x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))
    plt.title(title)
    plt.show()

# %%
visualize(X_no_noisy, y_no_noisy, "Datos sin ruido")

# %%
X_train,y_train,X_test,y_test = do_circles(2000, 0.05)

# %%
visualize(X_train, y_train, "Datos de entrenamiento")

# %%
visualize(X_test, y_test, "Datos de prueba")

# %% [markdown]
# Mediante la primera gráfica se puede ver como sería un dataset generado sin ruido. Luego se muestra el dataset de entrenamiento y prueba, respectivamente, con el 5% de ruido inducido.

# %% [markdown]
# Para lo que sigue, se utilizará la siguiente función para graficar las fronteras de clasificación en base a la probabilidad, definida por un algoritmo, de un ejemplo a pertenecer a una clase en particular.

# %%
def plot_classifier(clf,X_train,Y_train,X_test,Y_test,model_type):
    f, axis = plt.subplots(1, 1, sharex='col', sharey='row',figsize=(12, 8))
    axis.scatter(X_train[:,0],X_train[:,1],s=30,c=Y_train,zorder=10,cmap='cool')
    axis.scatter(X_test[:,0],X_test[:,1],s=20,c=Y_test,zorder=10,cmap='Greys')
    XX, YY = np.mgrid[-2:2:200j, -2:2:200j]
    if model_type == 'tree':
        Z = clf.predict_proba(np.c_[XX.ravel(), YY.ravel()])[:,0]
    elif model_type == 'ann':
        Z = clf.predict(np.c_[XX.ravel(), YY.ravel()])
    else: raise ValueError('model type not supported')
    Z = Z.reshape(XX.shape)
    Zplot = Z >= 0.5
    axis.pcolormesh(XX, YY, Zplot ,cmap='YlGn')
    axis.contour(XX, YY, Z, alpha=1, colors=["k", "k", "k"], linestyles=["--", "-", "--"],
    levels=[-2, 0, 2])
    plt.show()

# %% [markdown]
# ### b) Red neuronal artificial con una neurona

# %% [markdown]
# Se intenta resolver el problema de clasificación con una red neuronal artificial con solo una neurona, es decir, sin capas escondidas.

# %% [markdown]
# (b) Demuestre experimentalmente que una red neuronal artificial correspondiente a 1 sola neurona (i.e. sin capas escondidas) no puede resolver satisfactoriamente el problema. Puede utilizar la funci´on de activaci´on y el m´etodo de entrenamiento que prefiera. Sea convincente: por ejemplo, intente modificar los par´ametros de la m´aquina de aprendizaje, reportando m´etricas que permitan evaluar el desempe˜no del modelo en el problema con cada cambio efectuado. Adapte tambi´en la funci´on plot classifier para que represente gr´aficamente la soluci´on encontrada por la red neuronal. Describa y explique lo que observa, reportando gr´aficos de la soluci´on s´olo para algunos casos representativos.

# %% [markdown]
# Parámetros keras: No se usará regularizador
#
# * Layer: Dense
#     * units: primer numero que se pone, indica la dimensionalidad del output
#     * activation: funcion de activación que se usa, sin esto se usara a(x)=x. https://keras.io/activations/
#        Existe:
#        * linear
#        * sigmoid
#        * hard_sigmoid
#        * tanh
#        * relu
#        * softsign
#        * softplus
#        * selu
#        * elu
#        * softmax
#     * kernel_initializer: Initializer for the kernel weights https://keras.io/initializers/
#
#
# * Optimizadores disponibles: Solo usaré SGD porque los otros ni los cacho https://keras.io/optimizers/
#     * SGD
#     * RMSprop
#     * Adagrad
#     * Adam
#     * Adamax
#     * Nadam
#     * TFOptimizer
#
# * Funciones de perdida: https://keras.io/losses/
#     * mean_squared_error
#     * mean_absolute_error
#     * mean_absolute_percentage_error
#     * mean_squared_logarithmic_error
#     * squared_hinge
#     * hinge
#     * categorical_hinge
#     * logcosh
#     * categorical_crossentropy
#     * sparse_categorical_crossentropy
#     * binary_crossentropy
#     * kullback_leibler_divergence
#     * poisson
#     * cosine_proximity

# %% [markdown]
# El optimizador a utilizar en la siguiente sección será un gradiente descendente estocástico (SGD). En una primera instancia se aborda el problema con una capa de entrada con función de activación ReLU (rectified linear unit) y una inicialización de pesos con distribución uniforme y una capa de salida con una función de activación sigmoid. La función de perdida que se utilizará para el siguiente modelo será la Cross entropy binaria.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

n_h=1
model_sgd_1_relu = Sequential()

model_sgd_1_relu.add(Dense(1, input_dim=X_train.shape[1], kernel_initializer='uniform', activation='relu'))
model_sgd_1_relu.add(Dense(n_h, init='uniform', activation='sigmoid'))

model_sgd_1_relu.compile(optimizer=SGD(lr=1), loss='binary_crossentropy', metrics=['accuracy', 'mae', 'mse'])
model_sgd_1_relu.fit(X_train, y_train, epochs=50, batch_size=100, verbose=1)
scores = model_sgd_1_relu.evaluate(X_test, y_test)
test_acc = scores[1]
# Out:
# /home/fefi/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   if __name__ == '__main__':
# Epoch 1/50
# 1000/1000 [==============================] - 0s 269us/step - loss: 0.6949 - acc: 0.4930 - mean_absolute_error: 0.5006 - mean_squared_error: 0.2509
# Epoch 2/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6930 - acc: 0.5230 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2499
# Epoch 3/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6933 - acc: 0.5170 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2501
# Epoch 4/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6942 - acc: 0.4990 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2505
# Epoch 5/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6938 - acc: 0.4810 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2503
# Epoch 6/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6944 - acc: 0.4810 - mean_absolute_error: 0.5005 - mean_squared_error: 0.2506
# Epoch 7/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6935 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2502
# Epoch 8/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6942 - acc: 0.5190 - mean_absolute_error: 0.5002 - mean_squared_error: 0.2505
# Epoch 9/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6905 - acc: 0.5470 - mean_absolute_error: 0.4986 - mean_squared_error: 0.2487
# Epoch 10/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6882 - acc: 0.5690 - mean_absolute_error: 0.4971 - mean_squared_error: 0.2475
# Epoch 11/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6791 - acc: 0.6340 - mean_absolute_error: 0.4922 - mean_squared_error: 0.2430
# Epoch 12/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6660 - acc: 0.5810 - mean_absolute_error: 0.4844 - mean_squared_error: 0.2366
# Epoch 13/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6468 - acc: 0.6030 - mean_absolute_error: 0.4721 - mean_squared_error: 0.2278
# Epoch 14/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6274 - acc: 0.6460 - mean_absolute_error: 0.4579 - mean_squared_error: 0.2193
# Epoch 15/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6123 - acc: 0.6500 - mean_absolute_error: 0.4456 - mean_squared_error: 0.2139
# Epoch 16/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6012 - acc: 0.6570 - mean_absolute_error: 0.4364 - mean_squared_error: 0.2100
# Epoch 17/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5930 - acc: 0.6590 - mean_absolute_error: 0.4282 - mean_squared_error: 0.2075
# Epoch 18/50
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.5869 - acc: 0.6620 - mean_absolute_error: 0.4249 - mean_squared_error: 0.2059
# Epoch 19/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5832 - acc: 0.6680 - mean_absolute_error: 0.4209 - mean_squared_error: 0.2047
# Epoch 20/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.5810 - acc: 0.6720 - mean_absolute_error: 0.4181 - mean_squared_error: 0.2041
# Epoch 21/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5789 - acc: 0.6690 - mean_absolute_error: 0.4160 - mean_squared_error: 0.2038
# Epoch 22/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5764 - acc: 0.6690 - mean_absolute_error: 0.4152 - mean_squared_error: 0.2029
# Epoch 23/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5747 - acc: 0.6700 - mean_absolute_error: 0.4131 - mean_squared_error: 0.2026
# Epoch 24/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5743 - acc: 0.6720 - mean_absolute_error: 0.4127 - mean_squared_error: 0.2026
# Epoch 25/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.5730 - acc: 0.6680 - mean_absolute_error: 0.4099 - mean_squared_error: 0.2022
# Epoch 26/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5723 - acc: 0.6710 - mean_absolute_error: 0.4098 - mean_squared_error: 0.2019
# Epoch 27/50
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.5716 - acc: 0.6720 - mean_absolute_error: 0.4098 - mean_squared_error: 0.2018
# Epoch 28/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5721 - acc: 0.6710 - mean_absolute_error: 0.4098 - mean_squared_error: 0.2023
# Epoch 29/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5710 - acc: 0.6690 - mean_absolute_error: 0.4091 - mean_squared_error: 0.2019
# Epoch 30/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5705 - acc: 0.6710 - mean_absolute_error: 0.4082 - mean_squared_error: 0.2016
# Epoch 31/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5705 - acc: 0.6700 - mean_absolute_error: 0.4079 - mean_squared_error: 0.2019
# Epoch 32/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5691 - acc: 0.6720 - mean_absolute_error: 0.4076 - mean_squared_error: 0.2013
# Epoch 33/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5702 - acc: 0.6720 - mean_absolute_error: 0.4070 - mean_squared_error: 0.2019
# Epoch 34/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.5689 - acc: 0.6670 - mean_absolute_error: 0.4056 - mean_squared_error: 0.2015
# Epoch 35/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5691 - acc: 0.6730 - mean_absolute_error: 0.4072 - mean_squared_error: 0.2014
# Epoch 36/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5692 - acc: 0.6650 - mean_absolute_error: 0.4074 - mean_squared_error: 0.2018
# Epoch 37/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.5679 - acc: 0.6650 - mean_absolute_error: 0.4053 - mean_squared_error: 0.2012
# Epoch 38/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.5681 - acc: 0.6690 - mean_absolute_error: 0.4045 - mean_squared_error: 0.2013
# Epoch 39/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.5674 - acc: 0.6730 - mean_absolute_error: 0.4053 - mean_squared_error: 0.2009
# Epoch 40/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.5678 - acc: 0.6720 - mean_absolute_error: 0.4050 - mean_squared_error: 0.2012
# Epoch 41/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5672 - acc: 0.6700 - mean_absolute_error: 0.4039 - mean_squared_error: 0.2010
# Epoch 42/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5677 - acc: 0.6690 - mean_absolute_error: 0.4066 - mean_squared_error: 0.2011
# Epoch 43/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5668 - acc: 0.6710 - mean_absolute_error: 0.4027 - mean_squared_error: 0.2009
# Epoch 44/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.5671 - acc: 0.6710 - mean_absolute_error: 0.4065 - mean_squared_error: 0.2010
# Epoch 45/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.5667 - acc: 0.6720 - mean_absolute_error: 0.4037 - mean_squared_error: 0.2009
# Epoch 46/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.5657 - acc: 0.6720 - mean_absolute_error: 0.4015 - mean_squared_error: 0.2004
# Epoch 47/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5664 - acc: 0.6700 - mean_absolute_error: 0.4049 - mean_squared_error: 0.2009
# Epoch 48/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5663 - acc: 0.6700 - mean_absolute_error: 0.4037 - mean_squared_error: 0.2007
# Epoch 49/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5657 - acc: 0.6720 - mean_absolute_error: 0.4028 - mean_squared_error: 0.2004
# Epoch 50/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.5664 - acc: 0.6700 - mean_absolute_error: 0.4052 - mean_squared_error: 0.2009
# 1000/1000 [==============================] - 0s 152us/step

# %%
plot_classifier(model_sgd_1_relu,X_train,y_train,X_test,y_test,model_type = 'ann')

# %% [markdown]
# # mejorar yo cacho
# Como se puede ver con una SGD con tasa de aprendizaje 1, funciona mal, como era de esperar.

# %%
n_h=1
model_sgd_01_relu = Sequential()

model_sgd_01_relu.add(Dense(1, input_dim=X_train.shape[1], kernel_initializer='uniform', activation='relu'))
model_sgd_01_relu.add(Dense(n_h, init='uniform', activation='sigmoid'))

model_sgd_01_relu.compile(optimizer=SGD(lr=0.1), loss='binary_crossentropy', metrics=['accuracy', 'mae', 'mse'])
model_sgd_01_relu.fit(X_train, y_train, epochs=50, batch_size=100, verbose=1)
scores = model_sgd_01_relu.evaluate(X_test, y_test)
test_acc = scores[1]
# Out:
# /home/fefi/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   """
# Epoch 1/50
# 1000/1000 [==============================] - 0s 284us/step - loss: 0.6932 - acc: 0.5110 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 2/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6933 - acc: 0.5070 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2501
# Epoch 3/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.6932 - acc: 0.4950 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 4/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 5/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 6/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 7/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 8/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 9/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 10/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 11/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 12/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 13/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 14/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 15/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 16/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 17/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 18/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 19/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 20/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 21/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 22/50
# 1000/1000 [==============================] - 0s 14us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 23/50
# 1000/1000 [==============================] - 0s 11us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 24/50
# 1000/1000 [==============================] - 0s 13us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 25/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 26/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 27/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 28/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 29/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 30/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 31/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 32/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 33/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 34/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 35/50
# 1000/1000 [==============================] - 0s 14us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 36/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 37/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 38/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 39/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 40/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 41/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 42/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 43/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 44/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6924 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 45/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6924 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 46/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6923 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 47/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6924 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 48/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6921 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 49/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6920 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2494
# Epoch 50/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6920 - acc: 0.5640 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2494
# 1000/1000 [==============================] - 0s 149us/step

# %%
plot_classifier(model_sgd_01_relu,X_train,y_train,X_test,y_test,model_type = 'ann')

# %% [markdown]
# Cambiando solo la tasa de aprendizaje del SGD a 0.1, los resultados de la función de pérdida con el accuracy se intercambian y el error cuadrático aumenta un poco. Sin embargo, sigue funcionando mal.

# %% [markdown]
# Luego, se prueba cambiando la función de activación de la capa de entrada por una función elu, y volviendo a una tasa de aprendizaje de la SGD de 1.

# %%
n_h=1
model_sgd_1_sigmoid = Sequential()

model_sgd_1_sigmoid.add(Dense(1, input_dim=X_train.shape[1], kernel_initializer='uniform', activation='elu'))
model_sgd_1_sigmoid.add(Dense(n_h, init='uniform', activation='sigmoid'))

model_sgd_1_sigmoid.compile(optimizer=SGD(lr=1), loss='binary_crossentropy', metrics=['accuracy', 'mae', 'mse'])
model_sgd_1_sigmoid.fit(X_train, y_train, epochs=50, batch_size=100, verbose=1)
scores = model_sgd_1_sigmoid.evaluate(X_test, y_test)
test_acc = scores[1]
# Out:
# /home/fefi/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   """
# Epoch 1/50
# 1000/1000 [==============================] - 0s 298us/step - loss: 0.6944 - acc: 0.5030 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2506
# Epoch 2/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6944 - acc: 0.4990 - mean_absolute_error: 0.5005 - mean_squared_error: 0.2506
# Epoch 3/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6937 - acc: 0.4970 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2503
# Epoch 4/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6938 - acc: 0.5030 - mean_absolute_error: 0.5002 - mean_squared_error: 0.2503
# Epoch 5/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6940 - acc: 0.4870 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2504
# Epoch 6/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.6954 - acc: 0.5010 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2511
# Epoch 7/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6936 - acc: 0.4910 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2502
# Epoch 8/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6936 - acc: 0.4930 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2502
# Epoch 9/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6941 - acc: 0.4870 - mean_absolute_error: 0.5002 - mean_squared_error: 0.2505
# Epoch 10/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6940 - acc: 0.5110 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2504
# Epoch 11/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6941 - acc: 0.5010 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2505
# Epoch 12/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6933 - acc: 0.5130 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2501
# Epoch 13/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6945 - acc: 0.4770 - mean_absolute_error: 0.5005 - mean_squared_error: 0.2507
# Epoch 14/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6944 - acc: 0.5010 - mean_absolute_error: 0.5004 - mean_squared_error: 0.2506
# Epoch 15/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6940 - acc: 0.4610 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2504
# Epoch 16/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6942 - acc: 0.5070 - mean_absolute_error: 0.5002 - mean_squared_error: 0.2505
# Epoch 17/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6945 - acc: 0.4790 - mean_absolute_error: 0.5006 - mean_squared_error: 0.2507
# Epoch 18/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6948 - acc: 0.4600 - mean_absolute_error: 0.5007 - mean_squared_error: 0.2508
# Epoch 19/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6937 - acc: 0.4910 - mean_absolute_error: 0.5002 - mean_squared_error: 0.2503
# Epoch 20/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6939 - acc: 0.4950 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2504
# Epoch 21/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6938 - acc: 0.4970 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2503
# Epoch 22/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6943 - acc: 0.4850 - mean_absolute_error: 0.5003 - mean_squared_error: 0.2506
# Epoch 23/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6935 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2502
# Epoch 24/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6934 - acc: 0.4990 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2501
# Epoch 25/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6936 - acc: 0.5070 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2502
# Epoch 26/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6945 - acc: 0.4920 - mean_absolute_error: 0.5005 - mean_squared_error: 0.2507
# Epoch 27/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6947 - acc: 0.5060 - mean_absolute_error: 0.5004 - mean_squared_error: 0.2508
# Epoch 28/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6927 - acc: 0.5130 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 29/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6931 - acc: 0.5400 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2500
# Epoch 30/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6913 - acc: 0.4880 - mean_absolute_error: 0.4987 - mean_squared_error: 0.2491
# Epoch 31/50
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.6905 - acc: 0.4970 - mean_absolute_error: 0.4980 - mean_squared_error: 0.2487
# Epoch 32/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6901 - acc: 0.5970 - mean_absolute_error: 0.4974 - mean_squared_error: 0.2485
# Epoch 33/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6849 - acc: 0.6280 - mean_absolute_error: 0.4934 - mean_squared_error: 0.2458
# Epoch 34/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6783 - acc: 0.6460 - mean_absolute_error: 0.4886 - mean_squared_error: 0.2425
# Epoch 35/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6717 - acc: 0.5890 - mean_absolute_error: 0.4837 - mean_squared_error: 0.2396
# Epoch 36/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6629 - acc: 0.6130 - mean_absolute_error: 0.4755 - mean_squared_error: 0.2355
# Epoch 37/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6548 - acc: 0.6270 - mean_absolute_error: 0.4672 - mean_squared_error: 0.2320
# Epoch 38/50
# 1000/1000 [==============================] - 0s 15us/step - loss: 0.6461 - acc: 0.6260 - mean_absolute_error: 0.4612 - mean_squared_error: 0.2285
# Epoch 39/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6376 - acc: 0.6510 - mean_absolute_error: 0.4518 - mean_squared_error: 0.2250
# Epoch 40/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6329 - acc: 0.6500 - mean_absolute_error: 0.4468 - mean_squared_error: 0.2238
# Epoch 41/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6238 - acc: 0.6440 - mean_absolute_error: 0.4421 - mean_squared_error: 0.2202
# Epoch 42/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6193 - acc: 0.6480 - mean_absolute_error: 0.4385 - mean_squared_error: 0.2188
# Epoch 43/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.6126 - acc: 0.6660 - mean_absolute_error: 0.4313 - mean_squared_error: 0.2162
# Epoch 44/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6108 - acc: 0.6630 - mean_absolute_error: 0.4323 - mean_squared_error: 0.2161
# Epoch 45/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6037 - acc: 0.6730 - mean_absolute_error: 0.4249 - mean_squared_error: 0.2132
# Epoch 46/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6005 - acc: 0.6640 - mean_absolute_error: 0.4261 - mean_squared_error: 0.2123
# Epoch 47/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.5973 - acc: 0.6840 - mean_absolute_error: 0.4216 - mean_squared_error: 0.2108
# Epoch 48/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5943 - acc: 0.6800 - mean_absolute_error: 0.4195 - mean_squared_error: 0.2101
# Epoch 49/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5928 - acc: 0.6770 - mean_absolute_error: 0.4169 - mean_squared_error: 0.2097
# Epoch 50/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.5898 - acc: 0.6790 - mean_absolute_error: 0.4173 - mean_squared_error: 0.2086
# 1000/1000 [==============================] - 0s 158us/step

# %%
plot_classifier(model_sgd_1_sigmoid,X_train,y_train,X_test,y_test,model_type = 'ann')

# %% [markdown]
# Se puede observar como las métricas se mantienen en general muy parecidas, sin presentar una mejora.

# %%
n_h=1
model_sgd_01_sigmoid = Sequential()

model_sgd_01_sigmoid.add(Dense(1, input_dim=X_train.shape[1], kernel_initializer='uniform', activation='selu'))
model_sgd_01_sigmoid.add(Dense(n_h, init='uniform', activation='sigmoid'))

model_sgd_01_sigmoid.compile(optimizer=SGD(lr=0.1), loss='binary_crossentropy', metrics=['accuracy', 'mae', 'mse'])
model_sgd_01_sigmoid.fit(X_train, y_train, epochs=50, batch_size=100, verbose=1)
scores = model_sgd_01_sigmoid.evaluate(X_test, y_test)
test_acc = scores[1]
# Out:
# /home/fefi/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   """
# Epoch 1/50
# 1000/1000 [==============================] - 0s 259us/step - loss: 0.6932 - acc: 0.4960 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 2/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6931 - acc: 0.5320 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 3/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 4/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6931 - acc: 0.5110 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 5/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 6/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 7/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 8/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 9/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 10/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 11/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 12/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 13/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 14/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6928 - acc: 0.5500 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 15/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 16/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 17/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 18/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 19/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 20/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6929 - acc: 0.5390 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 21/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6927 - acc: 0.5540 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 22/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6926 - acc: 0.5080 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 23/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 24/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 25/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6925 - acc: 0.5590 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 26/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6924 - acc: 0.5540 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 27/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6923 - acc: 0.5570 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2496
# Epoch 28/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6923 - acc: 0.5580 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2496
# Epoch 29/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6923 - acc: 0.5640 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2496
# Epoch 30/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6923 - acc: 0.6550 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2496
# Epoch 31/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6921 - acc: 0.6430 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 32/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6921 - acc: 0.6180 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 33/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6920 - acc: 0.5840 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2494
# Epoch 34/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6918 - acc: 0.6410 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2493
# Epoch 35/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.6917 - acc: 0.6640 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2493
# Epoch 36/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6917 - acc: 0.6670 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2493
# Epoch 37/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6915 - acc: 0.6550 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2492
# Epoch 38/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6915 - acc: 0.6730 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2492
# Epoch 39/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6914 - acc: 0.6760 - mean_absolute_error: 0.4990 - mean_squared_error: 0.2491
# Epoch 40/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6913 - acc: 0.6830 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2491
# Epoch 41/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6913 - acc: 0.6770 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2491
# Epoch 42/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6912 - acc: 0.6610 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2490
# Epoch 43/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.6910 - acc: 0.6850 - mean_absolute_error: 0.4988 - mean_squared_error: 0.2489
# Epoch 44/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6908 - acc: 0.6610 - mean_absolute_error: 0.4987 - mean_squared_error: 0.2488
# Epoch 45/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6906 - acc: 0.6930 - mean_absolute_error: 0.4986 - mean_squared_error: 0.2487
# Epoch 46/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6905 - acc: 0.6910 - mean_absolute_error: 0.4985 - mean_squared_error: 0.2487
# Epoch 47/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6904 - acc: 0.6820 - mean_absolute_error: 0.4984 - mean_squared_error: 0.2486
# Epoch 48/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6902 - acc: 0.6770 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2485
# Epoch 49/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6901 - acc: 0.6500 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2485
# Epoch 50/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6900 - acc: 0.6690 - mean_absolute_error: 0.4981 - mean_squared_error: 0.2484
# 1000/1000 [==============================] - 0s 138us/step

# %%
plot_classifier(model_sgd_01_sigmoid,X_train,y_train,X_test,y_test,model_type = 'ann')

# %% [markdown]
# Con una función de activación selu en la capa de entrada se ve que mediante las metricas que no mejora mucho.

# %% [markdown]
# # *No analice los gráficos porque no los entendí xd*

# %% [markdown]
# ### c) Red neuronal artificial con una capa escondida

# %% [markdown]
# c) Demuestre experimentalmente que una red neuronal artificial con 1 capa escondida puede resolver satisfactoriamente el problema obtenido en (a). Puede utilizar la arquitectura y el m´etodo de entrenamiento que prefiera, pero en esta actividad puede optar tranquilamente por usar los hiper-par´ametros que se entregan como referencia en el c´odigo de ejemplo. Cambie el n´umero de neuronas Nh en la red entre 2 y 32 en potencias de 2, graficando el error de entrenamiento y pruebas como funci´on de Nh. Describa y explique lo que observa. Utilice la funci´on plot classifier, dise˜nada anteriormente, para construir gr´aficos de la soluci´on en algunos casos representativos.

# %%
X_train.shape
# Out:
# (1000, 2)

# %%
test_acc = [] 
train_acc = []
for i in range(1,6):
    n_h=2**i
    print n_h
    model = Sequential()
    model.add(Dense(n_h, input_dim=X_train.shape[1], kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    model.compile(optimizer=SGD(lr=0.1), loss='binary_crossentropy', metrics=['accuracy', 'mae', 'mse']) 

    model.fit(X_train, y_train, epochs=50, batch_size=100, verbose=1)
    scores = model.evaluate(X_test, y_test)
    test_acc.append(scores[1])
    scores = model.evaluate(X_train, y_train)
    train_acc.append(scores[1])
    plot_classifier(model,X_train,y_train,X_test,y_test,model_type = 'ann')
# Out:
# 2
# Epoch 1/50
# 1000/1000 [==============================] - 0s 409us/step - loss: 0.6932 - acc: 0.5120 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 2/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 3/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 4/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 5/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 6/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 7/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2500
# Epoch 8/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 9/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 10/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 11/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 12/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 13/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 14/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 15/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 16/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 17/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 18/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 19/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 20/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 21/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 22/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 23/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 24/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 25/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 26/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 27/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 28/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6926 - acc: 0.5130 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 29/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 30/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6924 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 31/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6923 - acc: 0.5260 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 32/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 33/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6922 - acc: 0.5130 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 34/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 35/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6920 - acc: 0.5100 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2494
# Epoch 36/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6918 - acc: 0.5100 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2493
# Epoch 37/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6916 - acc: 0.5140 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2492
# Epoch 38/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6915 - acc: 0.5350 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2492
# Epoch 39/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6913 - acc: 0.5820 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2491
# Epoch 40/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6912 - acc: 0.5410 - mean_absolute_error: 0.4990 - mean_squared_error: 0.2490
# Epoch 41/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6910 - acc: 0.6000 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2489
# Epoch 42/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6908 - acc: 0.6070 - mean_absolute_error: 0.4988 - mean_squared_error: 0.2488
# Epoch 43/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6905 - acc: 0.5810 - mean_absolute_error: 0.4986 - mean_squared_error: 0.2487
# Epoch 44/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6904 - acc: 0.6470 - mean_absolute_error: 0.4986 - mean_squared_error: 0.2486
# Epoch 45/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6901 - acc: 0.6230 - mean_absolute_error: 0.4984 - mean_squared_error: 0.2485
# Epoch 46/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6898 - acc: 0.6470 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2483
# Epoch 47/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6896 - acc: 0.6210 - mean_absolute_error: 0.4981 - mean_squared_error: 0.2482
# Epoch 48/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6891 - acc: 0.6660 - mean_absolute_error: 0.4979 - mean_squared_error: 0.2480
# Epoch 49/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6886 - acc: 0.6540 - mean_absolute_error: 0.4977 - mean_squared_error: 0.2477
# Epoch 50/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6882 - acc: 0.6650 - mean_absolute_error: 0.4975 - mean_squared_error: 0.2475
# 1000/1000 [==============================] - 0s 213us/step
# 1000/1000 [==============================] - 0s 31us/step
# 4
# Epoch 1/50
# 1000/1000 [==============================] - 0s 462us/step - loss: 0.6932 - acc: 0.4820 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 2/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 3/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 4/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 5/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 6/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 7/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 8/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 9/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 10/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2499
# Epoch 11/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 12/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6927 - acc: 0.5150 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 13/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 14/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 15/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 16/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 17/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 18/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 19/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6920 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2494
# Epoch 20/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6921 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 21/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6918 - acc: 0.5070 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2493
# Epoch 22/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6916 - acc: 0.5070 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2492
# Epoch 23/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6915 - acc: 0.5070 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2492
# Epoch 24/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6912 - acc: 0.5070 - mean_absolute_error: 0.4990 - mean_squared_error: 0.2490
# Epoch 25/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6910 - acc: 0.5070 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2489
# Epoch 26/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6908 - acc: 0.5190 - mean_absolute_error: 0.4988 - mean_squared_error: 0.2488
# Epoch 27/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6906 - acc: 0.5070 - mean_absolute_error: 0.4986 - mean_squared_error: 0.2487
# Epoch 28/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6903 - acc: 0.5430 - mean_absolute_error: 0.4985 - mean_squared_error: 0.2486
# Epoch 29/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6899 - acc: 0.5510 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2484
# Epoch 30/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6897 - acc: 0.5530 - mean_absolute_error: 0.4982 - mean_squared_error: 0.2483
# Epoch 31/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6891 - acc: 0.6470 - mean_absolute_error: 0.4979 - mean_squared_error: 0.2480
# Epoch 32/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6885 - acc: 0.6400 - mean_absolute_error: 0.4977 - mean_squared_error: 0.2477
# Epoch 33/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6880 - acc: 0.7030 - mean_absolute_error: 0.4974 - mean_squared_error: 0.2474
# Epoch 34/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6874 - acc: 0.6470 - mean_absolute_error: 0.4971 - mean_squared_error: 0.2471
# Epoch 35/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6869 - acc: 0.6760 - mean_absolute_error: 0.4968 - mean_squared_error: 0.2469
# Epoch 36/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6861 - acc: 0.7010 - mean_absolute_error: 0.4964 - mean_squared_error: 0.2465
# Epoch 37/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6854 - acc: 0.6990 - mean_absolute_error: 0.4960 - mean_squared_error: 0.2461
# Epoch 38/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6844 - acc: 0.7290 - mean_absolute_error: 0.4955 - mean_squared_error: 0.2456
# Epoch 39/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6833 - acc: 0.7930 - mean_absolute_error: 0.4950 - mean_squared_error: 0.2451
# Epoch 40/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6822 - acc: 0.7770 - mean_absolute_error: 0.4945 - mean_squared_error: 0.2445
# Epoch 41/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6812 - acc: 0.7800 - mean_absolute_error: 0.4939 - mean_squared_error: 0.2440
# Epoch 42/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6798 - acc: 0.7840 - mean_absolute_error: 0.4932 - mean_squared_error: 0.2433
# Epoch 43/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6781 - acc: 0.8030 - mean_absolute_error: 0.4923 - mean_squared_error: 0.2425
# Epoch 44/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6765 - acc: 0.7980 - mean_absolute_error: 0.4915 - mean_squared_error: 0.2417
# Epoch 45/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6747 - acc: 0.8160 - mean_absolute_error: 0.4905 - mean_squared_error: 0.2408
# Epoch 46/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6726 - acc: 0.8160 - mean_absolute_error: 0.4895 - mean_squared_error: 0.2398
# Epoch 47/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.6705 - acc: 0.8200 - mean_absolute_error: 0.4884 - mean_squared_error: 0.2387
# Epoch 48/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6682 - acc: 0.8110 - mean_absolute_error: 0.4871 - mean_squared_error: 0.2375
# Epoch 49/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6656 - acc: 0.8040 - mean_absolute_error: 0.4857 - mean_squared_error: 0.2362
# Epoch 50/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6625 - acc: 0.8190 - mean_absolute_error: 0.4841 - mean_squared_error: 0.2347
# 1000/1000 [==============================] - 0s 294us/step
# 1000/1000 [==============================] - 0s 39us/step
# 8
# Epoch 1/50
# 1000/1000 [==============================] - 0s 465us/step - loss: 0.6932 - acc: 0.5290 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 2/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6930 - acc: 0.5350 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 3/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6930 - acc: 0.5040 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 4/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 5/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 6/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2498
# Epoch 7/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 8/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 9/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6925 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2497
# Epoch 10/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 11/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 12/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6920 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2494
# Epoch 13/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6918 - acc: 0.5070 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2494
# Epoch 14/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6916 - acc: 0.5070 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2492
# Epoch 15/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6915 - acc: 0.5070 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2492
# Epoch 16/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6913 - acc: 0.5070 - mean_absolute_error: 0.4990 - mean_squared_error: 0.2491
# Epoch 17/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6910 - acc: 0.5070 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2489
# Epoch 18/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6908 - acc: 0.5070 - mean_absolute_error: 0.4988 - mean_squared_error: 0.2488
# Epoch 19/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6905 - acc: 0.5070 - mean_absolute_error: 0.4986 - mean_squared_error: 0.2487
# Epoch 20/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6902 - acc: 0.5090 - mean_absolute_error: 0.4985 - mean_squared_error: 0.2485
# Epoch 21/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6899 - acc: 0.5070 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2484
# Epoch 22/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6894 - acc: 0.5180 - mean_absolute_error: 0.4981 - mean_squared_error: 0.2481
# Epoch 23/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6891 - acc: 0.5070 - mean_absolute_error: 0.4979 - mean_squared_error: 0.2480
# Epoch 24/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6885 - acc: 0.5700 - mean_absolute_error: 0.4977 - mean_squared_error: 0.2477
# Epoch 25/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6879 - acc: 0.5460 - mean_absolute_error: 0.4974 - mean_squared_error: 0.2474
# Epoch 26/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6875 - acc: 0.7250 - mean_absolute_error: 0.4972 - mean_squared_error: 0.2472
# Epoch 27/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6867 - acc: 0.6370 - mean_absolute_error: 0.4967 - mean_squared_error: 0.2468
# Epoch 28/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6859 - acc: 0.6360 - mean_absolute_error: 0.4963 - mean_squared_error: 0.2464
# Epoch 29/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6853 - acc: 0.7550 - mean_absolute_error: 0.4961 - mean_squared_error: 0.2461
# Epoch 30/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6842 - acc: 0.7060 - mean_absolute_error: 0.4955 - mean_squared_error: 0.2456
# Epoch 31/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6831 - acc: 0.7540 - mean_absolute_error: 0.4949 - mean_squared_error: 0.2450
# Epoch 32/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6820 - acc: 0.7650 - mean_absolute_error: 0.4943 - mean_squared_error: 0.2444
# Epoch 33/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6807 - acc: 0.8140 - mean_absolute_error: 0.4937 - mean_squared_error: 0.2438
# Epoch 34/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6794 - acc: 0.8750 - mean_absolute_error: 0.4930 - mean_squared_error: 0.2431
# Epoch 35/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6778 - acc: 0.8610 - mean_absolute_error: 0.4922 - mean_squared_error: 0.2423
# Epoch 36/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6760 - acc: 0.8740 - mean_absolute_error: 0.4913 - mean_squared_error: 0.2414
# Epoch 37/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6742 - acc: 0.8800 - mean_absolute_error: 0.4904 - mean_squared_error: 0.2405
# Epoch 38/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6719 - acc: 0.9160 - mean_absolute_error: 0.4892 - mean_squared_error: 0.2394
# Epoch 39/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6696 - acc: 0.9390 - mean_absolute_error: 0.4880 - mean_squared_error: 0.2382
# Epoch 40/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6671 - acc: 0.9420 - mean_absolute_error: 0.4867 - mean_squared_error: 0.2370
# Epoch 41/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6643 - acc: 0.9540 - mean_absolute_error: 0.4852 - mean_squared_error: 0.2356
# Epoch 42/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6612 - acc: 0.9490 - mean_absolute_error: 0.4836 - mean_squared_error: 0.2341
# Epoch 43/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6578 - acc: 0.9510 - mean_absolute_error: 0.4818 - mean_squared_error: 0.2323
# Epoch 44/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6540 - acc: 0.9540 - mean_absolute_error: 0.4798 - mean_squared_error: 0.2305
# Epoch 45/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6500 - acc: 0.9620 - mean_absolute_error: 0.4777 - mean_squared_error: 0.2285
# Epoch 46/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6456 - acc: 0.9690 - mean_absolute_error: 0.4753 - mean_squared_error: 0.2263
# Epoch 47/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6409 - acc: 0.9750 - mean_absolute_error: 0.4728 - mean_squared_error: 0.2240
# Epoch 48/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6361 - acc: 0.9720 - mean_absolute_error: 0.4702 - mean_squared_error: 0.2216
# Epoch 49/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6306 - acc: 0.9780 - mean_absolute_error: 0.4672 - mean_squared_error: 0.2189
# Epoch 50/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6246 - acc: 0.9760 - mean_absolute_error: 0.4638 - mean_squared_error: 0.2159
# 1000/1000 [==============================] - 0s 266us/step
# 1000/1000 [==============================] - 0s 34us/step
# 16
# Epoch 1/50
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.6934 - acc: 0.4660 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2501
# Epoch 2/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6932 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 3/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 4/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6930 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 5/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6929 - acc: 0.5070 - mean_absolute_error: 0.4999 - mean_squared_error: 0.2499
# Epoch 6/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 7/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 8/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6926 - acc: 0.5070 - mean_absolute_error: 0.4997 - mean_squared_error: 0.2497
# Epoch 9/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6924 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 10/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 11/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 12/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.6921 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 13/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.6919 - acc: 0.5070 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2494
# Epoch 14/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.6916 - acc: 0.5070 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2492
# Epoch 15/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6915 - acc: 0.5380 - mean_absolute_error: 0.4992 - mean_squared_error: 0.2492
# Epoch 16/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6911 - acc: 0.5070 - mean_absolute_error: 0.4989 - mean_squared_error: 0.2490
# Epoch 17/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6909 - acc: 0.5070 - mean_absolute_error: 0.4988 - mean_squared_error: 0.2489
# Epoch 18/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6906 - acc: 0.5400 - mean_absolute_error: 0.4987 - mean_squared_error: 0.2487
# Epoch 19/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6903 - acc: 0.5070 - mean_absolute_error: 0.4985 - mean_squared_error: 0.2486
# Epoch 20/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6900 - acc: 0.5070 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2484
# Epoch 21/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6896 - acc: 0.6030 - mean_absolute_error: 0.4982 - mean_squared_error: 0.2482
# Epoch 22/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6891 - acc: 0.5660 - mean_absolute_error: 0.4979 - mean_squared_error: 0.2480
# Epoch 23/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6888 - acc: 0.6180 - mean_absolute_error: 0.4978 - mean_squared_error: 0.2478
# Epoch 24/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6883 - acc: 0.6550 - mean_absolute_error: 0.4975 - mean_squared_error: 0.2476
# Epoch 25/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6876 - acc: 0.5850 - mean_absolute_error: 0.4972 - mean_squared_error: 0.2472
# Epoch 26/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6869 - acc: 0.7310 - mean_absolute_error: 0.4968 - mean_squared_error: 0.2469
# Epoch 27/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6862 - acc: 0.7400 - mean_absolute_error: 0.4965 - mean_squared_error: 0.2465
# Epoch 28/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6853 - acc: 0.7850 - mean_absolute_error: 0.4960 - mean_squared_error: 0.2461
# Epoch 29/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6844 - acc: 0.7780 - mean_absolute_error: 0.4956 - mean_squared_error: 0.2456
# Epoch 30/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6834 - acc: 0.7970 - mean_absolute_error: 0.4951 - mean_squared_error: 0.2452
# Epoch 31/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6822 - acc: 0.7860 - mean_absolute_error: 0.4944 - mean_squared_error: 0.2445
# Epoch 32/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6809 - acc: 0.7900 - mean_absolute_error: 0.4938 - mean_squared_error: 0.2439
# Epoch 33/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6797 - acc: 0.7990 - mean_absolute_error: 0.4931 - mean_squared_error: 0.2433
# Epoch 34/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6781 - acc: 0.8010 - mean_absolute_error: 0.4923 - mean_squared_error: 0.2425
# Epoch 35/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6764 - acc: 0.8110 - mean_absolute_error: 0.4914 - mean_squared_error: 0.2416
# Epoch 36/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6744 - acc: 0.8100 - mean_absolute_error: 0.4904 - mean_squared_error: 0.2406
# Epoch 37/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6725 - acc: 0.8130 - mean_absolute_error: 0.4894 - mean_squared_error: 0.2397
# Epoch 38/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6701 - acc: 0.8100 - mean_absolute_error: 0.4882 - mean_squared_error: 0.2385
# Epoch 39/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6676 - acc: 0.8160 - mean_absolute_error: 0.4868 - mean_squared_error: 0.2372
# Epoch 40/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6650 - acc: 0.8130 - mean_absolute_error: 0.4855 - mean_squared_error: 0.2360
# Epoch 41/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6620 - acc: 0.8090 - mean_absolute_error: 0.4838 - mean_squared_error: 0.2345
# Epoch 42/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.6587 - acc: 0.8130 - mean_absolute_error: 0.4820 - mean_squared_error: 0.2328
# Epoch 43/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6553 - acc: 0.8080 - mean_absolute_error: 0.4802 - mean_squared_error: 0.2311
# Epoch 44/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6516 - acc: 0.8080 - mean_absolute_error: 0.4781 - mean_squared_error: 0.2293
# Epoch 45/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6475 - acc: 0.8160 - mean_absolute_error: 0.4759 - mean_squared_error: 0.2273
# Epoch 46/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6431 - acc: 0.8090 - mean_absolute_error: 0.4734 - mean_squared_error: 0.2251
# Epoch 47/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.6385 - acc: 0.8060 - mean_absolute_error: 0.4708 - mean_squared_error: 0.2228
# Epoch 48/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6335 - acc: 0.8280 - mean_absolute_error: 0.4681 - mean_squared_error: 0.2204
# Epoch 49/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6281 - acc: 0.8260 - mean_absolute_error: 0.4650 - mean_squared_error: 0.2178
# Epoch 50/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6225 - acc: 0.8320 - mean_absolute_error: 0.4618 - mean_squared_error: 0.2150
# 1000/1000 [==============================] - 0s 311us/step
# 1000/1000 [==============================] - 0s 37us/step
# 32
# Epoch 1/50
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.6935 - acc: 0.4740 - mean_absolute_error: 0.5002 - mean_squared_error: 0.2502
# Epoch 2/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.6933 - acc: 0.5070 - mean_absolute_error: 0.5001 - mean_squared_error: 0.2501
# Epoch 3/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6931 - acc: 0.5070 - mean_absolute_error: 0.5000 - mean_squared_error: 0.2500
# Epoch 4/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6928 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 5/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6927 - acc: 0.5070 - mean_absolute_error: 0.4998 - mean_squared_error: 0.2498
# Epoch 6/50
# 1000/1000 [==============================] - 0s 13us/step - loss: 0.6924 - acc: 0.5070 - mean_absolute_error: 0.4996 - mean_squared_error: 0.2496
# Epoch 7/50
# 1000/1000 [==============================] - 0s 12us/step - loss: 0.6922 - acc: 0.5070 - mean_absolute_error: 0.4995 - mean_squared_error: 0.2495
# Epoch 8/50
# 1000/1000 [==============================] - 0s 12us/step - loss: 0.6921 - acc: 0.5070 - mean_absolute_error: 0.4994 - mean_squared_error: 0.2495
# Epoch 9/50
# 1000/1000 [==============================] - 0s 12us/step - loss: 0.6918 - acc: 0.5070 - mean_absolute_error: 0.4993 - mean_squared_error: 0.2494
# Epoch 10/50
# 1000/1000 [==============================] - 0s 12us/step - loss: 0.6915 - acc: 0.5080 - mean_absolute_error: 0.4991 - mean_squared_error: 0.2492
# Epoch 11/50
# 1000/1000 [==============================] - 0s 12us/step - loss: 0.6912 - acc: 0.5070 - mean_absolute_error: 0.4990 - mean_squared_error: 0.2490
# Epoch 12/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.6909 - acc: 0.5070 - mean_absolute_error: 0.4988 - mean_squared_error: 0.2489
# Epoch 13/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6906 - acc: 0.5130 - mean_absolute_error: 0.4987 - mean_squared_error: 0.2487
# Epoch 14/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6903 - acc: 0.5070 - mean_absolute_error: 0.4985 - mean_squared_error: 0.2486
# Epoch 15/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6901 - acc: 0.5420 - mean_absolute_error: 0.4984 - mean_squared_error: 0.2485
# Epoch 16/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.6895 - acc: 0.5980 - mean_absolute_error: 0.4982 - mean_squared_error: 0.2482
# Epoch 17/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6892 - acc: 0.5810 - mean_absolute_error: 0.4980 - mean_squared_error: 0.2480
# Epoch 18/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.6887 - acc: 0.5800 - mean_absolute_error: 0.4977 - mean_squared_error: 0.2478
# Epoch 19/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6882 - acc: 0.5860 - mean_absolute_error: 0.4975 - mean_squared_error: 0.2475
# Epoch 20/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6876 - acc: 0.6760 - mean_absolute_error: 0.4972 - mean_squared_error: 0.2473
# Epoch 21/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.6871 - acc: 0.6680 - mean_absolute_error: 0.4969 - mean_squared_error: 0.2470
# Epoch 22/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6864 - acc: 0.7250 - mean_absolute_error: 0.4966 - mean_squared_error: 0.2466
# Epoch 23/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6855 - acc: 0.6950 - mean_absolute_error: 0.4961 - mean_squared_error: 0.2462
# Epoch 24/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6848 - acc: 0.7140 - mean_absolute_error: 0.4957 - mean_squared_error: 0.2458
# Epoch 25/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.6836 - acc: 0.7040 - mean_absolute_error: 0.4952 - mean_squared_error: 0.2453
# Epoch 26/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6827 - acc: 0.7360 - mean_absolute_error: 0.4947 - mean_squared_error: 0.2448
# Epoch 27/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6815 - acc: 0.7700 - mean_absolute_error: 0.4941 - mean_squared_error: 0.2442
# Epoch 28/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6803 - acc: 0.7850 - mean_absolute_error: 0.4935 - mean_squared_error: 0.2436
# Epoch 29/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6788 - acc: 0.8340 - mean_absolute_error: 0.4928 - mean_squared_error: 0.2428
# Epoch 30/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6774 - acc: 0.8550 - mean_absolute_error: 0.4920 - mean_squared_error: 0.2421
# Epoch 31/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.6755 - acc: 0.8470 - mean_absolute_error: 0.4911 - mean_squared_error: 0.2412
# Epoch 32/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.6738 - acc: 0.9190 - mean_absolute_error: 0.4902 - mean_squared_error: 0.2403
# Epoch 33/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6716 - acc: 0.9270 - mean_absolute_error: 0.4890 - mean_squared_error: 0.2392
# Epoch 34/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6693 - acc: 0.9790 - mean_absolute_error: 0.4879 - mean_squared_error: 0.2381
# Epoch 35/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6668 - acc: 0.9660 - mean_absolute_error: 0.4866 - mean_squared_error: 0.2368
# Epoch 36/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6639 - acc: 0.9860 - mean_absolute_error: 0.4851 - mean_squared_error: 0.2354
# Epoch 37/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6609 - acc: 0.9770 - mean_absolute_error: 0.4835 - mean_squared_error: 0.2339
# Epoch 38/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.6575 - acc: 1.0000 - mean_absolute_error: 0.4818 - mean_squared_error: 0.2322
# Epoch 39/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.6540 - acc: 1.0000 - mean_absolute_error: 0.4799 - mean_squared_error: 0.2304
# Epoch 40/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.6499 - acc: 1.0000 - mean_absolute_error: 0.4778 - mean_squared_error: 0.2284
# Epoch 41/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6455 - acc: 1.0000 - mean_absolute_error: 0.4755 - mean_squared_error: 0.2262
# Epoch 42/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6408 - acc: 1.0000 - mean_absolute_error: 0.4730 - mean_squared_error: 0.2239
# Epoch 43/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6355 - acc: 1.0000 - mean_absolute_error: 0.4702 - mean_squared_error: 0.2212
# Epoch 44/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6299 - acc: 1.0000 - mean_absolute_error: 0.4672 - mean_squared_error: 0.2184
# Epoch 45/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6238 - acc: 1.0000 - mean_absolute_error: 0.4639 - mean_squared_error: 0.2154
# Epoch 46/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6172 - acc: 1.0000 - mean_absolute_error: 0.4603 - mean_squared_error: 0.2121
# Epoch 47/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.6102 - acc: 1.0000 - mean_absolute_error: 0.4565 - mean_squared_error: 0.2087
# Epoch 48/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.6026 - acc: 1.0000 - mean_absolute_error: 0.4524 - mean_squared_error: 0.2049
# Epoch 49/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.5946 - acc: 1.0000 - mean_absolute_error: 0.4478 - mean_squared_error: 0.2010
# Epoch 50/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.5860 - acc: 1.0000 - mean_absolute_error: 0.4431 - mean_squared_error: 0.1968
# 1000/1000 [==============================] - 0s 378us/step
# 1000/1000 [==============================] - 0s 34us/step

# %% [markdown]
# Mediante la gráfica se puede ver que el último resultado obtenido, con 32 neuronas tiene un muy buen comportamiento separando correctamente el círculo interno del externo.

# %%
print test_acc
print train_acc
# Out:
# [0.68899999999999995, 0.80800000000000005, 0.98499999999999999, 0.80800000000000005, 1.0]
# [0.66500000000000004, 0.82499999999999996, 0.97699999999999998, 0.82999999999999996, 1.0]

# %%
import matplotlib.pyplot as plt
N_h = [2,4,8,16,32]

plt.figure(figsize=(12,6))  
plt.title("Acurracy segun numero de neuronas")
plt.xlabel("numero de neuronas")
plt.ylabel("accuracy")
indice = np.arange(5)   # Declara un array
plt.xticks(indice, N_h)   
plt.yticks(np.arange(0.0,1.0,0.1))
plt.plot(train_acc, marker='x', linestyle='--', color='b', label = "Entrenamiento")
plt.plot(test_acc, marker='*', linestyle='-', color='g', label = "Test")
plt.legend(loc="bottom left")
plt.show()
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/legend.py:325: UserWarning: Unrecognized location "bottom left". Falling back on "best"; valid locations are
# 	right
# 	center left
# 	upper right
# 	lower right
# 	best
# 	center
# 	lower left
# 	center right
# 	upper left
# 	upper center
# 	lower center
#
#   six.iterkeys(self.codes))))

# %% [markdown]
# Mediante el accuracy obtenido del test se puede ver que el comportamiento con la red de 32 neuronas funciona bien con un accuracy de un 100\%.
# Además el error de entrenamiento y prueba se comportan de una forma muy similar.

# %% [markdown]
# ### d) Árbol de clasificación de un nivel

# %% [markdown]
# d) Demuestre experimentalmente que stump (´arbol de clasificaci´on de 1 nivel) no puede resolver satisfactoriamente el problema anterior. Puede utilizar el criterio y la funci´on de partici´on que prefiera. Sea convincente: por ejemplo, intente modificar los par´ametros de la m´aquina, reportando m´etricas que permitan evaluar el desempe˜no del modelo en el problema con cada cambio efectuado. Adapte tambi´en la funci´on plot classifier para que represente gr´aficamente la soluci´on encontrada por el ´arbol. Describa y explique lo que observa, reportando gr´aficos de la soluci´on s´olo para algunos casos representativos.

# %% [markdown]
# Se procede a resolver el problema mediante un árbol de clasificación con un solo nivel.

# %% [markdown]
# Para la ejecución del árbol se pueden modificar los siguientes parámetros:
# * criterion: Mide la calidad de un split.
#     * gini
#     * entropy
# * splitter: Estrategia para elegir el splir en cada nodo.
#     * best
#     * random
# * max_depth: La profundidad máxima del árbol.

# %%
from sklearn.tree import DecisionTreeClassifier as Tree  #http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
clf_gini_best=Tree(criterion='gini',splitter='best',random_state=0,max_depth=1)
clf_gini_best.fit(X_train,y_train)
acc_test = clf_gini_best.score(X_test,y_test)
print "Test Accuracy = %f"%acc_test
print clf_gini_best.tree_.max_depth
plot_classifier(clf_gini_best,X_train,y_train,X_test,y_test,'tree')
# Out:
# Test Accuracy = 0.670000
# 1

# %%
clf_entropy_best=Tree(criterion='entropy',splitter='best',random_state=0,max_depth=1)
clf_entropy_best.fit(X_train,y_train)
acc_test = clf_entropy_best.score(X_test,y_test)
print "Test Accuracy = %f"%acc_test
print clf_entropy_best.tree_.max_depth
plot_classifier(clf_entropy_best,X_train,y_train,X_test,y_test,'tree')
# Out:
# Test Accuracy = 0.658000
# 1

# %%
clf_gini_random=Tree(criterion='gini',splitter='random',random_state=0,max_depth=1)
clf_gini_random.fit(X_train,y_train)
acc_test = clf_gini_random.score(X_test,y_test)
print "Test Accuracy = %f"%acc_test
print clf_gini_random.tree_.max_depth
plot_classifier(clf_gini_random,X_train,y_train,X_test,y_test,'tree')
# Out:
# Test Accuracy = 0.679000
# 1

# %%
clf_entropy=Tree(criterion='entropy',splitter='random',random_state=0,max_depth=1)
clf_entropy.fit(X_train,y_train)
acc_test = clf_entropy.score(X_test,y_test)
print "Test Accuracy = %f"%acc_test
print clf_entropy.tree_.max_depth
plot_classifier(clf_entropy,X_train,y_train,X_test,y_test,'tree')
# Out:
# Test Accuracy = 0.679000
# 1

# %% [markdown]
# Como es de esperar con un solo nivel del árbol no es posible resolver el problema que se tiene, pues el árbol de clasificación solo podrá dividir la región en dos.
#
# Como se ve en todos los gráficos anteriores, lo mecionado anteriormente ocurre con un accuracy común de 0.6 aproximadamente.

# %% [markdown]
# ### e) Árbol de clasificación con múltiples niveles

# %% [markdown]
# (e) Demuestre experimentalmente que un ´arbol de clasificaci´on de m´ultiples niveles puede resolver satisfactoriamente el problema estudiado. Puede utilizar el criterio y la funci´on de partici´on que prefiera, pero puede optar tranquilamente por usar los hiper-par´ametros que se entregan como referencia en el c´odigo de ejemplo. Cambie el n´umero de niveles admitidos en el ´arbol Nt entre 2 y 20, graficando el error de entrenamiento y pruebas como funci´on de Nt. Describa y explique lo que observa. Utilice la funci´on plot classifier, dise˜nada anteriormente, para construir gr´aficos de la soluci´on en algunos casos representativos.

# %% [markdown]
# Nuevamente el problema se enfrenta con árboles de clasificación, pero en esta ocasión se hará con más de uno, variando entre 2 y 20 niveles.

# %%
acc_test = []
acc_train = []
for i in range(2, 21):
    print i
    n_t = i
    clf=Tree(criterion='gini',splitter='best',random_state=0,max_depth=n_t)
    clf.fit(X_train,y_train)
    acc_test.append(clf.score(X_test,y_test))
    acc_train.append(clf.score(X_train,y_train))
    print "Test Accuracy = %f"%acc_test[-1]
    plot_classifier(clf,X_train,y_train,X_test,y_test,'tree')
# Out:
# 2
# Test Accuracy = 0.867000
# 3
# Test Accuracy = 0.924000
# 4
# Test Accuracy = 0.994000
# 5
# Test Accuracy = 0.992000
# 6
# Test Accuracy = 0.992000
# 7
# Test Accuracy = 0.992000
# 8
# Test Accuracy = 0.992000
# 9
# Test Accuracy = 0.992000
# 10
# Test Accuracy = 0.992000
# 11
# Test Accuracy = 0.992000
# 12
# Test Accuracy = 0.992000
# 13
# Test Accuracy = 0.992000
# 14
# Test Accuracy = 0.992000
# 15
# Test Accuracy = 0.992000
# 16
# Test Accuracy = 0.992000
# 17
# Test Accuracy = 0.992000
# 18
# Test Accuracy = 0.992000
# 19
# Test Accuracy = 0.992000
# 20
# Test Accuracy = 0.992000

# %% [markdown]
# Es posible ver mediante las gráficas que el árbol de clasificación con más de un nivel permite dividir el espacio en más regiones, llegando al punto en que pueda separar correctamente el círculo interior del exterior. De hecho, ya con un árbol de nivel 4 logra cumplir con la tarea.

# %%
levels = range(2,21)

plt.figure(figsize=(12,6))  
plt.title("Acurracy segun numero de neuronas")
plt.xlabel("numero de neuronas")
plt.ylabel("accuracy")
plt.xticks(levels)   
plt.plot(acc_train, marker='x', linestyle='--', color='b', label = "Entrenamiento")
plt.plot(acc_test, marker='*', linestyle='-', color='g', label = "Test")
plt.legend(loc="bottom left")
plt.show()

# %% [markdown]
# Mediante el acurracy es posible verificar lo mencionado anteriormente, con nivel meyor o igual a 4 se logra un buen acurracy, lo cual hace que separe bien los dos conjuntos de datos.

# %% [markdown]
# ### f) PCA con kernel gaussiano

# %% [markdown]
# (f) Como ya se demostr´o experimentalmente que este problema es linealmente inseperable, ahora se pide experimentar otra alternativa. Para ello deber´a realizar una proyecci´on de los datos a un nuevo espacio dimensional (manifold) en el cual se reconozcan sus patrones no lineales, para poder trabajarlos con fronteras lineales. Utilice la t´ecnica de PCA con la ayuda de un Kernel Gaussiano ([2]) para extraer sus vectores con dimensi´on infinita de mayor varianza.

# %% [markdown]
# Dado que ya hmos comrobado que el proble no es linealmente separable, se realiza una una proyección de los datos a un nuevo espacio dimensional,en el cual se reconozcan los patrones no lineales, para luego poder trabajarlos con fronteras lineales. Para lograr lo anterior, se utiliza la técnica de PCA con la ayuda de un Kernel Gaussiano para extraer sus vectores con dimensión infinita de mayor varianza.

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components=2,kernel="rbf", gamma=5)
kpca = kpca.fit(X_train)
Xkpca_train = kpca.transform(X_train)
Xkpca_test = kpca.transform(X_test)

# %%
#Graficar!!
def visualize(x,y,title=""):
    fig = plt.figure(figsize=(12,6))
    plt.scatter(x[:,0], x[:,1], s=50, c=y, cmap=plt.cm.winter)
    h = .02 # step size in the mesh
    x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))
    plt.title(title)
    plt.show()

# %%
visualize(Xkpca_test, y_test, "KernelPCA de test")

# %%
visualize(Xkpca_train, y_train, "KernelPCA de entrenamiento")

# %% [markdown]
# Luego, de aplicar Kernel PCA es pobile ver que en este nuevo espacio, los datos proyectados son separables linealmente.

# %% [markdown]
# ### g) Algoritmo de aprendizaje con fronteras lineal para los datos proyectados

# %% [markdown]
# (g) Ajuste un algoritmo de aprendizaje con fronteras lineal para los datos proyectados en este nuevo espacio que captura sus componentes no lineales, muestre graficamente que el problema ahora puede ser resulto con estos m´etodos. Reporte m´etricas para evaluar el desempe˜no, comente y concluya.

# %% [markdown]
# Dado que ya contamos con la proyección de lo datos en un nuevo espacio, en donde los datos son linelamente separados, se ajusta un modelo que trabaja con fronteras lineales para poder resolver este problema.

# %%
def visualize_border(model,x,y,title=""):
    fig = plt.figure(figsize=(12,6))
    plt.scatter(x[:,0], x[:,1], s=50, c=y, cmap=plt.cm.winter)
    h = .02 # step size in the mesh
    x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
    plt.title(title)
    plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import accuracy_score, classification_report
model = LDA()
model.fit(Xkpca_train,y_train)
visualize_border(model,Xkpca_train,y_train,"LDA")

y_true = y_test
y_pred = model.predict(Xkpca_test)
model.predict(Xkpca_test)
print("Miss Classification Loss: %f"%(1-accuracy_score(y_true, y_pred)))
print classification_report(y_true,model.predict(Xkpca_test))
# Out:
# Miss Classification Loss: 0.000000
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       507
#           1       1.00      1.00      1.00       493
#
# avg / total       1.00      1.00      1.00      1000

# %%
from sklearn.linear_model import LogisticRegression as LR
clf_lr = LR()
clf_lr.set_params(penalty='l2')
clf_lr.fit(Xkpca_train,y_train)
predicted = clf_lr.predict(Xkpca_test)
predicted_train = clf_lr.predict(Xkpca_train)


visualize_border(clf_lr,Xkpca_train,y_train,"Regresion Logistica")

print "Accuracy train Regresion Logistica :",(accuracy_score(y_train,predicted_train))   
print "Accuracy test Regresion Logistica:",(accuracy_score(y_test,predicted))
print classification_report(y_true,clf_lr.predict(Xkpca_test))
# Out:
# Accuracy train Regresion Logistica : 1.0
# Accuracy test Regresion Logistica: 1.0
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       507
#           1       1.00      1.00      1.00       493
#
# avg / total       1.00      1.00      1.00      1000
